# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
df_all = pd.read_csv("Annual net sales revenue of Amazon from 2004 to 2021.csv")
df_all
# Out:
#     year  sales_revenue
# 0   2004           6.92
# 1   2005           8.49
# 2   2006          10.71
# 3   2007          14.84
# 4   2008          19.17
# 5   2009          24.51
# 6   2010          34.20
# 7   2011          48.08
# 8   2012          61.09
# 9   2013          74.45
# 10  2014          88.99
# 11  2015         107.01
# 12  2016         135.99
# 13  2017         177.87
# 14  2018         232.89
# 15  2019         280.52
# 16  2020         386.06
# 17  2021         469.82

# %%
df_all.dtypes
# Out:
# year               int64
# sales_revenue    float64
# dtype: object

# %%
df_all["year"] = df_all["year"].astype(str)

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1, 1, 1)
ax.bar(df_all["year"], df_all["sales_revenue"])
ax.set_xlabel('year')
ax.set_ylabel('Sales revenue(billion US dollars)')
plt.xticks(rotation=60)
plt.title('Sales from 2004 to 2021')
fig.show()
#fig.savefig('normal graph.png')
# Out:
# /var/folders/p0/929y8gm10wn_vxfvzswzkltw0000gn/T/ipykernel_20875/2715270103.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('year')
ax.set_ylabel('Sales revenue(billion US dollars)')
ax.plot(df_all['year'], df_all['sales_revenue'])
plt.title('Sales from 2004 to 2021')
plt.xticks(rotation=60)
plt.show()
#fig.savefig('normal graph_2.png')

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('year')
ax.set_ylabel('log Sales revenue(billion US dollars)')
ax.plot(df_all['year'], df_all['sales_revenue'])
plt.yscale('log')
plt.title('Log Sales')
plt.xticks(rotation=60)
plt.show()
#fig.savefig('log graph.png')

# %% [markdown]
# ### メモ
# - 2009-2011くらいで若干傾きが大きくなってて増加率が上がってる？（→スマホの影響かな？👉2010-2013年で爆増してて、おそらく関係してる）https://www.soumu.go.jp/johotsusintokei/whitepaper/ja/r03/html/nd111100.html#:~:text=%E3%81%9D%E3%81%AE%E4%B8%AD%E3%81%A7%E3%82%82%E3%80%81%E3%82%B9%E3%83%9E%E3%83%BC%E3%83%88%E3%83%95%E3%82%A9%E3%83%B3%E3%81%AE%E6%99%AE%E5%8F%8A,1%2D1%2D1%EF%BC%89%E3%80%82&text=%E3%81%BE%E3%81%9F%E3%80%812020%E5%B9%B4%E3%81%AE%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%BC%E3%83%8D%E3%83%83%E3%83%88,1%2D1%2D2%EF%BC%89%E3%80%82）
#
# - 2015-2018くらいで若干傾きが大きくなってて増加率が上がってる？（→クラウド事業が好調だからかも）https://kinsta.com/jp/aws-market-share/
#
# - 2019-2022くらいで若干傾きが大きくなってて増加率が上がってる？（→COVIDの影響かと思われる）
